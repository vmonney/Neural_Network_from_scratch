# %% [markdown]
# # Introducing Optimization

# %%
import numpy as np
import matplotlib.pyplot as plt
import nnfs
from nnfs.datasets import vertical_data

nnfs.init()

# %%
X, y = vertical_data(samples=100, classes=3)

plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap="brg")
plt.show()

# %%
# Dense layer
class Layer_Dense:
    # Layer initialization
    def __init__(self, n_inputs, n_neurons):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))

    # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs, weights and biases
        self.output = np.dot(inputs, self.weights) + self.biases


# ReLU activation
class Activation_ReLU:
    # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs
        self.output = np.maximum(0, inputs)


# Softmax activation
class Activation_Softmax:
    # Forward pass
    def forward(self, inputs):
        # Get unnormalized probabilities
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        # Normalize them for each sample
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)

        self.output = probabilities


# Common loss class
class Loss:
    # Calculates the data and regularization losses
    # given model output and ground truth values
    def calculate(self, output, y):
        # Calculate sample losses
        sample_losses = self.forward(output, y)

        # Calculate mean loss
        data_loss = np.mean(sample_losses)

        # Return loss
        return data_loss


# Cross-entropy loss
class Loss_CategoricalCrossentropy(Loss):
    # Forward pass
    def forward(self, y_pred, y_true):
        # Number of samples in a batch
        samples = len(y_pred)

        # Clip data to prevent division by 0
        # Clip both sides to not drag mean towards any value
        y_pred_clipped = np.clip(y_pred, 1e-7, 1 - 1e-7)

        # Probabilities for target values -
        # only if categorical labels
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[range(samples), y_true]

        # Mask values - only for one-hot encoded labels
        elif len(y_true.shape) == 2:
            correct_confidences = np.sum(y_pred_clipped * y_true, axis=1)

        # Losses
        negative_log_likelihoods = -np.log(correct_confidences)
        return negative_log_likelihoods

# %%
# Create dataset
X, y = vertical_data(samples=100, classes=3)

# Create model
dense1 = Layer_Dense(2, 3)  # first dense layer, 2 inputs
activation1 = Activation_ReLU()
dense2 = Layer_Dense(3, 3)  # second dense layer, 3 inputs, 3 outputs
activation2 = Activation_Softmax()

# Create loss function
loss_function = Loss_CategoricalCrossentropy()

# %%
# Helper variables
lowest_loss = 9999999  # some initial value
best_dense1_weights = dense1.weights.copy()
best_dense1_biases = dense1.biases.copy()
best_dense2_weights = dense2.weights.copy()
best_dense2_biases = dense2.biases.copy()

# %%
for iteration in range(10000):
    # Update weights with some small random values
    dense1.weights += 0.05 * np.random.randn(2, 3)
    dense1.biases += 0.05 * np.random.randn(1, 3)
    dense2.weights += 0.05 * np.random.randn(3, 3)
    dense2.biases = +0.05 * np.random.randn(1, 3)

    # Perform a forward pass of the training data through this layer
    dense1.forward(X)
    activation1.forward(dense1.output)
    dense2.forward(activation1.output)
    activation2.forward(dense2.output)

    # Perform a forward pass through activation function
    # it takes the output of second dense layer here and returns loss
    loss = loss_function.calculate(activation2.output, y)

    # Calculate accuracy from output of activation2 and targets
    predictions = np.argmax(activation2.output, axis=1)
    accuracy = np.mean(predictions == y)

    # If loss is smaller - print and save weights and biases aside
    if loss < lowest_loss:
        print(
            "New set of weights found, iteration:",
            iteration,
            "loss:",
            loss,
            "acc:",
            accuracy,
        )
        best_dense1_weights = dense1.weights.copy()
        best_dense1_biases = dense1.biases.copy()
        best_dense2_weights = dense2.weights.copy()
        best_dense2_biases = dense2.biases.copy()
        lowest_loss = loss
    # Revert weights and biases
    else:
        dense1.weights = best_dense1_weights.copy()
        dense1.biases = best_dense1_biases.copy()
        dense2.weights = best_dense2_weights.copy()
        dense2.biases = best_dense2_biases.copy()
# Out:
# New set of weights found, iteration: 0 loss: 1.099292 acc: 0.3333333333333333
# New set of weights found, iteration: 2 loss: 1.0987829 acc: 0.3333333333333333
# New set of weights found, iteration: 6 loss: 1.0986792 acc: 0.3333333333333333
# New set of weights found, iteration: 26 loss: 1.0981442 acc: 0.3333333333333333
# New set of weights found, iteration: 28 loss: 1.0961598 acc: 0.3566666666666667
# New set of weights found, iteration: 30 loss: 1.0943534 acc: 0.3333333333333333
# New set of weights found, iteration: 31 loss: 1.090979 acc: 0.6266666666666667
# New set of weights found, iteration: 32 loss: 1.0848355 acc: 0.57
# New set of weights found, iteration: 38 loss: 1.0788959 acc: 0.3333333333333333
# New set of weights found, iteration: 40 loss: 1.0647526 acc: 0.37666666666666665
# New set of weights found, iteration: 42 loss: 1.0565344 acc: 0.63
# New set of weights found, iteration: 44 loss: 1.0503016 acc: 0.8433333333333334
# New set of weights found, iteration: 52 loss: 1.0485015 acc: 0.8166666666666667
# New set of weights found, iteration: 64 loss: 1.0395246 acc: 0.6433333333333333
# New set of weights found, iteration: 67 loss: 1.0375087 acc: 0.6466666666666666
# New set of weights found, iteration: 70 loss: 1.0354354 acc: 0.7666666666666667
# New set of weights found, iteration: 71 loss: 1.0326695 acc: 0.8
# New set of weights found, iteration: 72 loss: 1.0304822 acc: 0.92
# New set of weights found, iteration: 76 loss: 1.0236908 acc: 0.8566666666666667
# New set of weights found, iteration: 78 loss: 1.0211303 acc: 0.63
# New set of weights found, iteration: 79 loss: 1.0135725 acc: 0.9
# New set of weights found, iteration: 80 loss: 1.0094532 acc: 0.6533333333333333
# New set of weights found, iteration: 85 loss: 1.005813 acc: 0.3566666666666667
# New set of weights found, iteration: 86 loss: 1.0021725 acc: 0.6066666666666667
# New set of weights found, iteration: 91 loss: 0.988605 acc: 0.69
# New set of weights found, iteration: 92 loss: 0.97934246 acc: 0.6
# New set of weights found, iteration: 94 loss: 0.9666136 acc: 0.5
# New set of weights found, iteration: 95 loss: 0.95292926 acc: 0.62
# New set of weights found, iteration: 100 loss: 0.95041525 acc: 0.6533333333333333
# New set of weights found, iteration: 103 loss: 0.94542795 acc: 0.6533333333333333
# New set of weights found, iteration: 106 loss: 0.9453786 acc: 0.6466666666666666
# New set of weights found, iteration: 111 loss: 0.93151814 acc: 0.6466666666666666
# New set of weights found, iteration: 115 loss: 0.9164345 acc: 0.7133333333333334
# New set of weights found, iteration: 120 loss: 0.9126872 acc: 0.6366666666666667
# New set of weights found, iteration: 123 loss: 0.9062343 acc: 0.8533333333333334
# New set of weights found, iteration: 125 loss: 0.89608234 acc: 0.5433333333333333
# New set of weights found, iteration: 126 loss: 0.89166373 acc: 0.6933333333333334
# New set of weights found, iteration: 128 loss: 0.88988996 acc: 0.72
# New set of weights found, iteration: 129 loss: 0.8869812 acc: 0.44666666666666666
# New set of weights found, iteration: 130 loss: 0.8696702 acc: 0.5833333333333334
# New set of weights found, iteration: 134 loss: 0.86664206 acc: 0.6333333333333333
# New set of weights found, iteration: 135 loss: 0.85789835 acc: 0.72
# New set of weights found, iteration: 136 loss: 0.8521176 acc: 0.5066666666666667
# New set of weights found, iteration: 139 loss: 0.8425144 acc: 0.5033333333333333
# New set of weights found, iteration: 144 loss: 0.8421519 acc: 0.63
# New set of weights found, iteration: 147 loss: 0.8185322 acc: 0.6433333333333333
# New set of weights found, iteration: 156 loss: 0.81102747 acc: 0.78
# New set of weights found, iteration: 158 loss: 0.79540133 acc: 0.7466666666666667
# New set of weights found, iteration: 163 loss: 0.79247385 acc: 0.7133333333333334
# New set of weights found, iteration: 164 loss: 0.7796931 acc: 0.8433333333333334
# New set of weights found, iteration: 170 loss: 0.7774535 acc: 0.7533333333333333
# New set of weights found, iteration: 172 loss: 0.767706 acc: 0.7333333333333333
# New set of weights found, iteration: 176 loss: 0.76311475 acc: 0.7966666666666666
# New set of weights found, iteration: 178 loss: 0.7559788 acc: 0.74
# New set of weights found, iteration: 181 loss: 0.74592257 acc: 0.8566666666666667
# New set of weights found, iteration: 188 loss: 0.74486464 acc: 0.86
# New set of weights found, iteration: 192 loss: 0.7437584 acc: 0.69
# New set of weights found, iteration: 193 loss: 0.7413533 acc: 0.8233333333333334
# New set of weights found, iteration: 195 loss: 0.7185369 acc: 0.7766666666666666
# New set of weights found, iteration: 202 loss: 0.71230084 acc: 0.81
# New set of weights found, iteration: 204 loss: 0.70807403 acc: 0.86
# New set of weights found, iteration: 205 loss: 0.70458704 acc: 0.9133333333333333
# New set of weights found, iteration: 206 loss: 0.70134777 acc: 0.8766666666666667
# New set of weights found, iteration: 210 loss: 0.6925111 acc: 0.9133333333333333
# New set of weights found, iteration: 211 loss: 0.691263 acc: 0.8733333333333333
# New set of weights found, iteration: 212 loss: 0.6866567 acc: 0.8766666666666667
# New set of weights found, iteration: 213 loss: 0.6763817 acc: 0.82
# New set of weights found, iteration: 214 loss: 0.67223054 acc: 0.9066666666666666
# New set of weights found, iteration: 217 loss: 0.65477407 acc: 0.9133333333333333
# New set of weights found, iteration: 222 loss: 0.6484494 acc: 0.8533333333333334
# New set of weights found, iteration: 225 loss: 0.6454918 acc: 0.9233333333333333
# New set of weights found, iteration: 227 loss: 0.63023 acc: 0.9233333333333333
# New set of weights found, iteration: 228 loss: 0.6238302 acc: 0.8666666666666667
# New set of weights found, iteration: 231 loss: 0.6190904 acc: 0.9033333333333333
# New set of weights found, iteration: 233 loss: 0.6095985 acc: 0.91
# New set of weights found, iteration: 239 loss: 0.6043349 acc: 0.9
# New set of weights found, iteration: 243 loss: 0.5846776 acc: 0.8933333333333333
# New set of weights found, iteration: 245 loss: 0.5813334 acc: 0.8966666666666666
# New set of weights found, iteration: 247 loss: 0.571068 acc: 0.8966666666666666
# New set of weights found, iteration: 249 loss: 0.56796324 acc: 0.8966666666666666
# New set of weights found, iteration: 251 loss: 0.56273085 acc: 0.8966666666666666
# New set of weights found, iteration: 256 loss: 0.55534554 acc: 0.9
# New set of weights found, iteration: 263 loss: 0.5419276 acc: 0.8933333333333333
# New set of weights found, iteration: 266 loss: 0.53338885 acc: 0.8933333333333333
# New set of weights found, iteration: 272 loss: 0.52791214 acc: 0.8833333333333333
# New set of weights found, iteration: 277 loss: 0.52734727 acc: 0.87
# New set of weights found, iteration: 280 loss: 0.51886374 acc: 0.93
# New set of weights found, iteration: 282 loss: 0.5149367 acc: 0.92
# New set of weights found, iteration: 283 loss: 0.51197886 acc: 0.93
# New set of weights found, iteration: 285 loss: 0.5105686 acc: 0.93
# New set of weights found, iteration: 289 loss: 0.5092543 acc: 0.9333333333333333
# New set of weights found, iteration: 292 loss: 0.49417192 acc: 0.9266666666666666
# New set of weights found, iteration: 298 loss: 0.4893663 acc: 0.9133333333333333
# New set of weights found, iteration: 304 loss: 0.48763216 acc: 0.93
# New set of weights found, iteration: 310 loss: 0.48420486 acc: 0.9333333333333333
# New set of weights found, iteration: 313 loss: 0.47819966 acc: 0.9366666666666666
# New set of weights found, iteration: 317 loss: 0.47766256 acc: 0.9366666666666666
# New set of weights found, iteration: 321 loss: 0.47221246 acc: 0.9066666666666666
# New set of weights found, iteration: 324 loss: 0.46427542 acc: 0.9333333333333333
# New set of weights found, iteration: 326 loss: 0.46043563 acc: 0.93
# New set of weights found, iteration: 336 loss: 0.45885366 acc: 0.9266666666666666
# New set of weights found, iteration: 337 loss: 0.45408773 acc: 0.89
# New set of weights found, iteration: 338 loss: 0.4482489 acc: 0.92
# New set of weights found, iteration: 346 loss: 0.44726065 acc: 0.8966666666666666
# New set of weights found, iteration: 350 loss: 0.4363867 acc: 0.9266666666666666
# New set of weights found, iteration: 357 loss: 0.43476948 acc: 0.9366666666666666
# New set of weights found, iteration: 362 loss: 0.42775562 acc: 0.9266666666666666
# New set of weights found, iteration: 365 loss: 0.4269102 acc: 0.9233333333333333
# New set of weights found, iteration: 373 loss: 0.4255644 acc: 0.9266666666666666
# New set of weights found, iteration: 374 loss: 0.42538124 acc: 0.9233333333333333
# New set of weights found, iteration: 380 loss: 0.42269805 acc: 0.93
# New set of weights found, iteration: 384 loss: 0.42126766 acc: 0.9233333333333333
# New set of weights found, iteration: 387 loss: 0.41108453 acc: 0.9166666666666666
# New set of weights found, iteration: 391 loss: 0.3963624 acc: 0.9333333333333333
# New set of weights found, iteration: 401 loss: 0.3930039 acc: 0.9266666666666666
# New set of weights found, iteration: 402 loss: 0.38951167 acc: 0.9333333333333333
# New set of weights found, iteration: 403 loss: 0.378293 acc: 0.9366666666666666
# New set of weights found, iteration: 408 loss: 0.37554505 acc: 0.9366666666666666
# New set of weights found, iteration: 409 loss: 0.3742779 acc: 0.9333333333333333
# New set of weights found, iteration: 410 loss: 0.3733835 acc: 0.9333333333333333
# New set of weights found, iteration: 411 loss: 0.37241215 acc: 0.9233333333333333
# New set of weights found, iteration: 412 loss: 0.36492255 acc: 0.9366666666666666
# New set of weights found, iteration: 422 loss: 0.3607358 acc: 0.9366666666666666
# New set of weights found, iteration: 423 loss: 0.35261118 acc: 0.9333333333333333
# New set of weights found, iteration: 425 loss: 0.34821165 acc: 0.9166666666666666
# New set of weights found, iteration: 430 loss: 0.3442424 acc: 0.9233333333333333
# New set of weights found, iteration: 432 loss: 0.34245494 acc: 0.9333333333333333
# New set of weights found, iteration: 443 loss: 0.341524 acc: 0.93
# New set of weights found, iteration: 449 loss: 0.34143093 acc: 0.9333333333333333
# New set of weights found, iteration: 451 loss: 0.3410198 acc: 0.9266666666666666
# New set of weights found, iteration: 455 loss: 0.3308192 acc: 0.9333333333333333
# New set of weights found, iteration: 459 loss: 0.3300392 acc: 0.9333333333333333
# New set of weights found, iteration: 462 loss: 0.32943675 acc: 0.9366666666666666
# New set of weights found, iteration: 464 loss: 0.3288337 acc: 0.9333333333333333
# New set of weights found, iteration: 466 loss: 0.32559285 acc: 0.9333333333333333
# New set of weights found, iteration: 476 loss: 0.32416007 acc: 0.9266666666666666
# New set of weights found, iteration: 477 loss: 0.32381782 acc: 0.9366666666666666
# New set of weights found, iteration: 484 loss: 0.32262325 acc: 0.9266666666666666
# New set of weights found, iteration: 490 loss: 0.32241052 acc: 0.9366666666666666
# New set of weights found, iteration: 492 loss: 0.32170564 acc: 0.9333333333333333
# New set of weights found, iteration: 497 loss: 0.31805694 acc: 0.93
# New set of weights found, iteration: 498 loss: 0.31753397 acc: 0.9266666666666666
# New set of weights found, iteration: 500 loss: 0.31232414 acc: 0.93
# New set of weights found, iteration: 501 loss: 0.30930397 acc: 0.9333333333333333
# New set of weights found, iteration: 505 loss: 0.30764186 acc: 0.9333333333333333
# New set of weights found, iteration: 509 loss: 0.30616716 acc: 0.9333333333333333
# New set of weights found, iteration: 510 loss: 0.30347246 acc: 0.93
# New set of weights found, iteration: 511 loss: 0.2928797 acc: 0.9333333333333333
# New set of weights found, iteration: 513 loss: 0.2896163 acc: 0.9333333333333333
# New set of weights found, iteration: 515 loss: 0.2857183 acc: 0.9333333333333333
# New set of weights found, iteration: 522 loss: 0.28529832 acc: 0.93
# New set of weights found, iteration: 524 loss: 0.28365284 acc: 0.9366666666666666
# New set of weights found, iteration: 526 loss: 0.28080857 acc: 0.94
# New set of weights found, iteration: 533 loss: 0.28058523 acc: 0.9333333333333333
# New set of weights found, iteration: 534 loss: 0.27907464 acc: 0.9333333333333333
# New set of weights found, iteration: 538 loss: 0.27716756 acc: 0.9333333333333333
# New set of weights found, iteration: 539 loss: 0.27411994 acc: 0.9366666666666666
# New set of weights found, iteration: 542 loss: 0.2731234 acc: 0.93
# New set of weights found, iteration: 549 loss: 0.26907998 acc: 0.9333333333333333
# New set of weights found, iteration: 559 loss: 0.26406687 acc: 0.9366666666666666
# New set of weights found, iteration: 577 loss: 0.26109323 acc: 0.9333333333333333
# New set of weights found, iteration: 578 loss: 0.25766265 acc: 0.9333333333333333
# New set of weights found, iteration: 590 loss: 0.25503856 acc: 0.9333333333333333
# New set of weights found, iteration: 592 loss: 0.25361812 acc: 0.93
# New set of weights found, iteration: 594 loss: 0.2495093 acc: 0.9333333333333333
# New set of weights found, iteration: 595 loss: 0.2464565 acc: 0.9333333333333333
# New set of weights found, iteration: 619 loss: 0.24583821 acc: 0.9366666666666666
# New set of weights found, iteration: 625 loss: 0.24259132 acc: 0.9366666666666666
# New set of weights found, iteration: 631 loss: 0.24213769 acc: 0.9366666666666666
# New set of weights found, iteration: 633 loss: 0.2366082 acc: 0.9333333333333333
# New set of weights found, iteration: 639 loss: 0.23107809 acc: 0.94
# New set of weights found, iteration: 646 loss: 0.22994992 acc: 0.9366666666666666
# New set of weights found, iteration: 651 loss: 0.22809362 acc: 0.9333333333333333
# New set of weights found, iteration: 656 loss: 0.22674693 acc: 0.93
# New set of weights found, iteration: 658 loss: 0.22658178 acc: 0.9433333333333334
# New set of weights found, iteration: 692 loss: 0.22517964 acc: 0.9333333333333333
# New set of weights found, iteration: 707 loss: 0.21969889 acc: 0.9366666666666666
# New set of weights found, iteration: 708 loss: 0.21924604 acc: 0.94
# New set of weights found, iteration: 711 loss: 0.21758087 acc: 0.93
# New set of weights found, iteration: 712 loss: 0.21414058 acc: 0.93
# New set of weights found, iteration: 713 loss: 0.21233392 acc: 0.9333333333333333
# New set of weights found, iteration: 717 loss: 0.21158975 acc: 0.9366666666666666
# New set of weights found, iteration: 720 loss: 0.20856772 acc: 0.94
# New set of weights found, iteration: 725 loss: 0.20692365 acc: 0.93
# New set of weights found, iteration: 726 loss: 0.20280911 acc: 0.93
# New set of weights found, iteration: 732 loss: 0.20194432 acc: 0.9333333333333333
# New set of weights found, iteration: 733 loss: 0.19958335 acc: 0.9333333333333333
# New set of weights found, iteration: 741 loss: 0.19941758 acc: 0.9333333333333333
# New set of weights found, iteration: 746 loss: 0.19920161 acc: 0.9333333333333333
# New set of weights found, iteration: 756 loss: 0.19873942 acc: 0.9333333333333333
# New set of weights found, iteration: 761 loss: 0.1970579 acc: 0.9333333333333333
# New set of weights found, iteration: 762 loss: 0.1964204 acc: 0.9333333333333333
# New set of weights found, iteration: 763 loss: 0.1943432 acc: 0.9333333333333333
# New set of weights found, iteration: 776 loss: 0.19406365 acc: 0.94
# New set of weights found, iteration: 783 loss: 0.19367257 acc: 0.9333333333333333
# New set of weights found, iteration: 792 loss: 0.19333056 acc: 0.9333333333333333
# New set of weights found, iteration: 794 loss: 0.19324714 acc: 0.9366666666666666
# New set of weights found, iteration: 795 loss: 0.19208804 acc: 0.9366666666666666
# New set of weights found, iteration: 797 loss: 0.18983111 acc: 0.9333333333333333
# New set of weights found, iteration: 810 loss: 0.1898017 acc: 0.9266666666666666
# New set of weights found, iteration: 812 loss: 0.18934494 acc: 0.9433333333333334
# New set of weights found, iteration: 814 loss: 0.18443255 acc: 0.9366666666666666
# New set of weights found, iteration: 832 loss: 0.18362935 acc: 0.9333333333333333
# New set of weights found, iteration: 835 loss: 0.18309455 acc: 0.9366666666666666
# New set of weights found, iteration: 836 loss: 0.18015026 acc: 0.93
# New set of weights found, iteration: 848 loss: 0.17968926 acc: 0.9366666666666666
# New set of weights found, iteration: 849 loss: 0.17854863 acc: 0.9366666666666666
# New set of weights found, iteration: 855 loss: 0.1775345 acc: 0.9366666666666666
# New set of weights found, iteration: 867 loss: 0.17541018 acc: 0.9366666666666666
# New set of weights found, iteration: 877 loss: 0.17512907 acc: 0.9333333333333333
# New set of weights found, iteration: 913 loss: 0.17448969 acc: 0.9366666666666666
# New set of weights found, iteration: 915 loss: 0.17307433 acc: 0.9366666666666666
# New set of weights found, iteration: 917 loss: 0.17306165 acc: 0.9366666666666666
# New set of weights found, iteration: 921 loss: 0.17243473 acc: 0.9366666666666666
# New set of weights found, iteration: 930 loss: 0.17206915 acc: 0.9366666666666666
# New set of weights found, iteration: 955 loss: 0.17148091 acc: 0.9333333333333333
# New set of weights found, iteration: 1022 loss: 0.17130232 acc: 0.9366666666666666
# New set of weights found, iteration: 1025 loss: 0.17092387 acc: 0.9366666666666666
# New set of weights found, iteration: 1027 loss: 0.17057373 acc: 0.9366666666666666
# New set of weights found, iteration: 1085 loss: 0.1705374 acc: 0.9366666666666666
# New set of weights found, iteration: 1117 loss: 0.16989882 acc: 0.9366666666666666
# New set of weights found, iteration: 1136 loss: 0.16919161 acc: 0.9366666666666666
# New set of weights found, iteration: 1159 loss: 0.16914141 acc: 0.9366666666666666
# New set of weights found, iteration: 1179 loss: 0.16904971 acc: 0.9366666666666666
# New set of weights found, iteration: 1204 loss: 0.16891405 acc: 0.9333333333333333
# New set of weights found, iteration: 1222 loss: 0.1682439 acc: 0.9366666666666666
# New set of weights found, iteration: 1239 loss: 0.16807322 acc: 0.94
# New set of weights found, iteration: 1256 loss: 0.16775149 acc: 0.94
# New set of weights found, iteration: 1293 loss: 0.16756223 acc: 0.9333333333333333
# New set of weights found, iteration: 1317 loss: 0.16744311 acc: 0.9366666666666666
# New set of weights found, iteration: 1321 loss: 0.16738541 acc: 0.9366666666666666
# New set of weights found, iteration: 1333 loss: 0.16734318 acc: 0.93
# New set of weights found, iteration: 1339 loss: 0.16710083 acc: 0.9366666666666666
# New set of weights found, iteration: 1346 loss: 0.16706768 acc: 0.9366666666666666
# New set of weights found, iteration: 1348 loss: 0.16651402 acc: 0.94
# New set of weights found, iteration: 1453 loss: 0.1664405 acc: 0.94
# New set of weights found, iteration: 1455 loss: 0.16616116 acc: 0.9333333333333333
# New set of weights found, iteration: 1468 loss: 0.16610953 acc: 0.93
# New set of weights found, iteration: 1471 loss: 0.16558856 acc: 0.94
# New set of weights found, iteration: 1481 loss: 0.16538766 acc: 0.94
# New set of weights found, iteration: 1526 loss: 0.16537541 acc: 0.94
# New set of weights found, iteration: 1529 loss: 0.16524866 acc: 0.9366666666666666
# New set of weights found, iteration: 1578 loss: 0.16520353 acc: 0.94
# New set of weights found, iteration: 1787 loss: 0.16505636 acc: 0.94
# New set of weights found, iteration: 1794 loss: 0.1650558 acc: 0.9366666666666666
# New set of weights found, iteration: 1881 loss: 0.16491254 acc: 0.9366666666666666
# New set of weights found, iteration: 2358 loss: 0.1648528 acc: 0.9366666666666666
# New set of weights found, iteration: 2662 loss: 0.16483593 acc: 0.9366666666666666
# New set of weights found, iteration: 2663 loss: 0.16480069 acc: 0.9366666666666666
# New set of weights found, iteration: 3001 loss: 0.16478428 acc: 0.9366666666666666
# New set of weights found, iteration: 3008 loss: 0.16473907 acc: 0.94
# New set of weights found, iteration: 3042 loss: 0.16467926 acc: 0.9366666666666666
# New set of weights found, iteration: 3047 loss: 0.1645889 acc: 0.9366666666666666
# New set of weights found, iteration: 3213 loss: 0.16451311 acc: 0.9366666666666666
# New set of weights found, iteration: 3334 loss: 0.1644408 acc: 0.9333333333333333
# New set of weights found, iteration: 4502 loss: 0.16442853 acc: 0.9333333333333333
# New set of weights found, iteration: 4638 loss: 0.1644232 acc: 0.9333333333333333
# New set of weights found, iteration: 4750 loss: 0.16441254 acc: 0.9366666666666666
# New set of weights found, iteration: 4763 loss: 0.16437861 acc: 0.9333333333333333
# New set of weights found, iteration: 4826 loss: 0.16435836 acc: 0.9333333333333333
# New set of weights found, iteration: 5029 loss: 0.16433877 acc: 0.9333333333333333
# New set of weights found, iteration: 5168 loss: 0.16431649 acc: 0.9333333333333333
# New set of weights found, iteration: 6066 loss: 0.16429535 acc: 0.9333333333333333
# New set of weights found, iteration: 6509 loss: 0.16429044 acc: 0.9333333333333333
